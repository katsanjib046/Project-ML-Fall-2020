# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt

ts = TimeSeries(key='VHH6FJCTM668RNG1', output_format='pandas')
data, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='full')
data19 = data[:500]
data19['1. open'].plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()

# %%
# directly downloading the file
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=1min&outputsize=full&apikey=VHH6FJCTM668RNG1&datatype=csv'
#import pandas as pd

df = pd.read_csv(url)   
df.head()
# Out:
#              timestamp    open    high     low   close  volume
# 0  2020-11-19 19:19:00  116.47  116.47  116.47  116.47    1000
# 1  2020-11-19 18:38:00  116.45  116.45  116.45  116.45     119
# 2  2020-11-19 18:20:00  116.30  116.30  116.30  116.30     210
# 3  2020-11-19 18:03:00  116.28  116.28  116.28  116.28     272
# 4  2020-11-19 18:01:00  116.43  116.43  116.43  116.43     296

# %%
df.to_csv('ibm_check.csv')

# %%
url='https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=MSFT&outputsize=full&apikey=VHH6FJCTM668RNG1&datatype=csv'
df = pd.read_csv(url)   
df
# Out:
#        timestamp    open     high     low   close    volume
# 0     2020-11-20  212.20  213.285  210.00  210.39  22403804
# 1     2020-11-19  211.38  213.030  209.93  212.42  24792746
# 2     2020-11-18  213.65  215.170  210.93  211.08  28372789
# 3     2020-11-17  216.10  217.680  214.08  214.46  24154112
# 4     2020-11-16  214.87  217.740  214.52  217.23  24953344
# ...          ...     ...      ...     ...     ...       ...
# 5295  1999-11-05   91.81   92.870   90.50   91.56  35083700
# 5296  1999-11-04   92.31   92.750   90.31   91.75  27119700
# 5297  1999-11-03   92.94   93.500   91.50   92.00  22258500
# 5298  1999-11-02   92.75   94.500   91.94   92.56  23174500
# 5299  1999-11-01   93.25   94.190   92.12   92.37  26630600
#
# [5300 rows x 6 columns]

# %%
df.set_index('timestamp')
df['close'].plot()
plt.title('Daily Times Series for the MSFT stock')
plt.show()

# %%
df.head()
# Out:
#     timestamp    open     high     low   close    volume
# 0  2020-11-20  212.20  213.285  210.00  210.39  22403804
# 1  2020-11-19  211.38  213.030  209.93  212.42  24792746
# 2  2020-11-18  213.65  215.170  210.93  211.08  28372789
# 3  2020-11-17  216.10  217.680  214.08  214.46  24154112
# 4  2020-11-16  214.87  217.740  214.52  217.23  24953344
